# %% [markdown]
# [Creating and Populating a Bigtable Instance](https://www.cloudskillsboost.google/focuses/58495?catalog_rank=%7B%22rank%22%3A7%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&parent=catalog&search_id=23847517)

# %% [markdown]
# ![2023-05-20 18_31_32-Tworzenie i wypełnianie instancji Bigtable _ Zwiększenie umiejętności Google Clo.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-20 18_40_50-Tworzenie i wypełnianie instancji Bigtable _ Zwiększenie umiejętności Google Clo.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-20 18_43_30-Tworzenie i wypełnianie instancji Bigtable _ Zwiększenie umiejętności Google Clo.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-20 18_43_53-Creating and Populating a Bigtable Instance _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-20 18_48_01-Bigtable – qwiklabs-gcp-00-a54… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-20 18_48_48-Bigtable – qwiklabs-gcp-00-a54… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-20 18_52_35-Tworzenie i wypełnianie instancji Bigtable _ Zwiększenie umiejętności Google Clo.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-20 18_57_44-personalized-sales – Tables – Bigtable – qwiklabs-gcp-00-a54… – Google Cloud con.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-20 18_58_25-Tworzenie i wypełnianie instancji Bigtable _ Zwiększenie umiejętności Google Clo.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-20 19_02_18-Tworzenie i wypełnianie instancji Bigtable _ Zwiększenie umiejętności Google Clo.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-20 19_04_11-Creating and Populating a Bigtable Instance _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gs://cloud-training/OCBL377/retail-interactions-sales-00000-of-00001

gs://qwiklabs-gcp-00-a54adcb0bf05/temp

# %% [markdown]
# ![2023-05-20 19_07_33-Tworzenie i wypełnianie instancji Bigtable _ Zwiększenie umiejętności Google Clo.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-20 19_07_58-Create job from template – Dataflow – qwiklabs-gcp-00-a54… – Google Cloud consol.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-20 19_09_51-import-usersessions – Dataflow – qwiklabs-gcp-00-a54… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-20 19_10_29-Tworzenie i wypełnianie instancji Bigtable _ Zwiększenie umiejętności Google Clo.png](data:image/png;base64,...)

# %%
echo project = `gcloud config get-value project` \
    >> ~/.cbtrc

# %% [markdown]
# ![2023-05-20 19_12_06-personalized-sales – Tables – Bigtable – qwiklabs-gcp-00-a54… – Google Cloud con.png](data:image/png;base64,...)

# %%
echo instance = personalized-sales \
    >> ~/.cbtrc

# %% [markdown]
# ![2023-05-20 19_12_36-personalized-sales – Tables – Bigtable – qwiklabs-gcp-00-a54… – Google Cloud con.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-20 19_12_52-Tworzenie i wypełnianie instancji Bigtable _ Zwiększenie umiejętności Google Clo.png](data:image/png;base64,...)

# %%
cat ~/.cbtrc

# %% [markdown]
# ![2023-05-20 19_13_19-personalized-sales – Tables – Bigtable – qwiklabs-gcp-00-a54… – Google Cloud con.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-20 19_13_51-Tworzenie i wypełnianie instancji Bigtable _ Zwiększenie umiejętności Google Clo.png](data:image/png;base64,...)

# %%
cbt read UserSessions \
    count=10

# %% [markdown]
# ![2023-05-20 19_16_00-Creating and Populating a Bigtable Instance _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-20 19_15_23-personalized-sales – Tables – Bigtable – qwiklabs-gcp-00-a54… – Google Cloud con.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-20 19_16_22-Tworzenie i wypełnianie instancji Bigtable _ Zwiększenie umiejętności Google Clo.png](data:image/png;base64,...)
