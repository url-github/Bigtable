# %% [markdown]
# [Bigtable: Qwik Start - Command Line](https://www.cloudskillsboost.google/focuses/579?catalog_rank=%7B%22rank%22%3A6%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&parent=catalog&search_id=23664769)

# %% [markdown]
# ![2023-05-05 12_50_28-Bigtable_ Qwik Start - Wiersz poleceń _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 12_52_03-Bigtable_ Qwik Start - Wiersz poleceń _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 12_52_31-Bigtable_ Qwik Start - Command Line _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
	# quickstart-instance

# %% [markdown]
# ![2023-05-05 12_56_58-Bigtable – qwiklabs-gcp-01-c6b… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 12_58_17-Bigtable_ Qwik Start - Wiersz poleceń _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
echo project = `gcloud config get-value project` > ~/.cbtrc

# %% [markdown]
# ![2023-05-05 13_00_27-Bigtable – qwiklabs-gcp-01-c6b… – Google Cloud console.png](data:image/png;base64,...)

# %%
echo instance = quickstart-instance >> ~/.cbtrc

# %% [markdown]
# ![2023-05-05 13_02_13-Bigtable – qwiklabs-gcp-01-c6b… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 13_02_50-Bigtable_ Qwik Start - Wiersz poleceń _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 13_03_21-Bigtable_ Qwik Start - Wiersz poleceń _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
cbt createtable my-table

# %% [markdown]
# ![2023-05-05 13_14_14-Bigtable – qwiklabs-gcp-01-c6b… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 13_15_06-quickstart-instance – Tables – Bigtable – qwiklabs-gcp-01-c6b… – Google Cloud co.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 13_15_41-Bigtable_ Qwik Start - Wiersz poleceń _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
cbt ls

# %% [markdown]
# ![2023-05-05 13_16_52-Bigtable_ Qwik Start - Wiersz poleceń _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 13_17_07-quickstart-instance – Tables – Bigtable – qwiklabs-gcp-01-c6b… – Google Cloud co.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 13_17_39-Bigtable_ Qwik Start - Wiersz poleceń _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
cbt createfamily my-table cf1

# %% [markdown]
# ![2023-05-05 13_18_33-quickstart-instance – Tables – Bigtable – qwiklabs-gcp-01-c6b… – Google Cloud co.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 13_19_15-my-table – Bigtable – qwiklabs-gcp-01-c6b… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 13_20_41-Bigtable_ Qwik Start - Wiersz poleceń _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
cbt ls my-table

# %% [markdown]
# ![2023-05-05 13_21_13-Dashboard – qwiklabs-gcp-01-c6b… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 13_21_34-Bigtable_ Qwik Start - Wiersz poleceń _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
cbt set my-table r1 cf1:c1=test-value

# %% [markdown]
# ![2023-05-05 13_22_45-Search – qwiklabs-gcp-01-c6b… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 13_23_07-Bigtable_ Qwik Start - Wiersz poleceń _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
cbt read my-table

# %% [markdown]
# ![2023-05-05 13_23_57-Search – qwiklabs-gcp-01-c6b… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 13_24_23-Bigtable_ Qwik Start - Wiersz poleceń _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
cbt deletetable my-table

# %% [markdown]
# ![2023-05-05 13_24_52-Search – qwiklabs-gcp-01-c6b… – Google Cloud console.png](data:image/png;base64,...)

# %%
cbt read my-table

# %% [markdown]
# ![2023-05-05 13_25_56-Search – qwiklabs-gcp-01-c6b… – Google Cloud console.png](data:image/png;base64,...)
